# %% [markdown]
# # Pretrained Models - Kunskapskontroll

# %% [markdown]
# **Obligatoriskt att fylla i uppgifterna nedan.**
#
# Namn: Ahmad Zalkat
#
# Vem du har presenterat för: Mustapha Hadrous, Lina Shideda
#
# Datum då du presenterade: 2024-05-08
#
# **Kunskapskontrollen lämnas in på Omniway.**

# %% [markdown]
# **It is possible to load pretrained models which is a powerful concept.**

# %% [markdown]
# Model implementation:
# https://keras.io/api/applications/#usage-examples-for-image-classification-models
#
# Class list for ResNet50, for example tennis ball is 852:
# https://deeplearning.cms.waikato.ac.nz/user-guide/class-maps/IMAGENET/

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
model = ResNet50(weights='imagenet')

# %%
# img_path = 'zebra.jpg'
# img_path = 'linjal.jpg'
img_path = 'tennisboll.jpg'
img = image.load_img(img_path, target_size=(224, 224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x.shape
# Out:
# (224, 224, 3)

# %%
x = np.expand_dims(x, axis=0)
x.shape
# Out:
# (1, 224, 224, 3)

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/resnet50/preprocess_input
x = preprocess_input(x)

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Predicted: [('n04409515', 'tennis_ball', 0.9999969), ('n04039381', 'racket', 2.7497174e-06), ('n03942813', 'ping-pong_ball', 5.5178763e-08)]

# %% [markdown]
# # 1. Take some pictures yourself and predict their class.

# %%
img_path1 = '1.jpg'
img1 = image.load_img(img_path1, target_size=(224,224))
img1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x1 = image.img_to_array(img1)
x1.shape
# Out:
# (224, 224, 3)

# %%
x1 = np.expand_dims(x1, axis=0)
x1.shape
# Out:
# (1, 224, 224, 3)

# %%
x1 = preprocess_input(x1)

# %%
preds1 = model.predict(x1)
print('Predicted:', decode_predictions(preds1, top=1)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Predicted: [('n07749582', 'lemon', 0.49781755)]

# %% [markdown]
# # Another code example to predict images folder

# %%
img_folder = 'images'

# %%
img_files = [f for f in os.listdir(img_folder) if f.endswith('.jpg')]

# %%
for img_file in img_files:
    img_path = os.path.join(img_folder, img_file)

    # Load the image and show it 
    img = image.load_img(img_path, target_size=(224, 224))
    plt.imshow(img)
    plt.show()

    # Preprocess image
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)

    # prediction and print class
    preds = model.predict(x)
    top_preds = decode_predictions(preds, top=1)[0]
    print(f'Predicted for {img_file}:')
    for pred in top_preds:
       # print(f'Class: {pred[1]}, Probability: {pred[2]:.2f}')
        print('Predicted:', decode_predictions(preds, top=1)[0])
    print()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# Predicted for 1.jpg:
# Predicted: [('n07749582', 'lemon', 0.49781755)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Predicted for 2.jpg:
# Predicted: [('n02607072', 'anemone_fish', 0.9270431)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# Predicted for 3.jpg:
# Predicted: [('n02129604', 'tiger', 0.9294437)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Predicted for linjal.jpg:
# Predicted: [('n03777754', 'modem', 0.6294243)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Predicted for zebra.jpg:
# Predicted: [('n02391049', 'zebra', 0.9864265)]

# %% [markdown]
# # 2. Answer the question: Why is "Pretrained models" a very powerful concept?

# %% [markdown]
# Pretrained models are a powerful concept in machine learning because

# %% [markdown]
# Take advantage of pre-existing knowledge, improve performance, save time  and resources while often achieving better performance.
